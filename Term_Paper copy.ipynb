# %% [markdown]
# # Term Paper

# %% [markdown]
# ### Part 1

# %%
# task 3
df["wid"].nunique()

# task 4
df["date"].first()
df["date"].last()

# or if sorted values needed
df = df["date"].sort_values()
first = df["date"].first()
last = df["date"].last()

query
